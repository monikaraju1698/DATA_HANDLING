# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
a=pd.read_csv(r"C:\Users\SDR\Desktop\iris.csv")

# %%
a.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
a.loc[0:3]=np.nan
a
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      NaN            NaN           NaN            NaN           NaN
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4       Iris-setosa
# ...

# %%
a
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      NaN            NaN           NaN            NaN           NaN
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4       Iris-setosa
# ...

# %%
a.shape
# Out:
# (150, 6)

# %%
a.count()
# Out:
# Id               146
# SepalLengthCm    146
# SepalWidthCm     146
# PetalLengthCm    146
# PetalWidthCm     146
# Species          146
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             146 non-null    float64
#  1   SepalLengthCm  146 non-null    float64
#  2   SepalWidthCm   146 non-null    float64
#  3   PetalLengthCm  146 non-null    float64
#  4   PetalWidthCm   146 non-null    float64
#  5   Species        146 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %%
a.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
a.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  146.000000     146.000000    146.000000     146.000000    146.000000
# mean    77.500000       5.871233      3.050000       3.823288      1.226027
# std     42.290661       0.821098      0.437745       1.743917      0.755125
# min      5.000000       4.300000      2.000000       1.000000      0.100000
# 25%     41.250000       5.125000      2.800000       1.600000      0.325000
# 50%     77.500000       5.800000      3.000000       4.400000      1.300000
# 75%    113.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
a.shape[1]
# Out:
# 6

# %%
a.loc[3:9]
a
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      NaN            NaN           NaN            NaN           NaN
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4       Iris-setosa
# ...

# %%
pd.isna(a)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0     True           True          True           True          True     True
# 1     True           True          True           True          True     True
# 2     True           True          True           True          True     True
# 3     True           True          True           True          True     True
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
pd.isna(a).sum()
# Out:
# Id               4
# SepalLengthCm    4
# SepalWidthCm     4
# PetalLengthCm    4
# PetalWidthCm     4
# Species          4
# dtype: int64

# %%
pd.isnull(a)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0     True           True          True           True          True     True
# 1     True           True          True           True          True     True
# 2     True           True          True           True          True     True
# 3     True           True          True           True          True     True
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
len(a)
# Out:
# 150

# %%
a.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\SDR\Desktop\iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.iloc[1:4]=np.nan
df.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  NaN            NaN           NaN            NaN           NaN          NaN
# 2  NaN            NaN           NaN            NaN           NaN          NaN
# 3  NaN            NaN           NaN            NaN           NaN          NaN
# 4  5.0            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isna()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1     True           True          True           True          True     True
# 2     True           True          True           True          True     True
# 3     True           True          True           True          True     True
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.fillna(df.mean())
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2               NaN
# 3               NaN
# 4       Iris-setosa
# ...

# %%
df.fillna(8)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      8.0            8.0           8.0            8.0           8.0
# 2      8.0            8.0           8.0            8.0           8.0
# 3      8.0            8.0           8.0            8.0           8.0
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1                 8
# 2                 8
# 3                 8
# 4       Iris-setosa
# ...

# %%
df.iloc[3:4]=np.nan
df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2               NaN
# 3               NaN
# 4       Iris-setosa
# ...
